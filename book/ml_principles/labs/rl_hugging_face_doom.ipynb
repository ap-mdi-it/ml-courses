# %% [markdown]
# # _Doom_ PPO
#
# In dit labo bekijken we de 🤗 [Hugging Face tutorial](https://huggingface.co/learn/deep-rl-course/en/unit8/hands-on-sf) over het gebruik van _Proximal Policy Optimization_ bij de videogame _Doom_.
#
# Deze tutorial maakt deel uit van de warm aanbevolen [Deep RL Course](https://huggingface.co/learn/deep-rl-course/en/unit0/introduction) van 🤗 Hugging Face.

# %% [markdown]
# [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=grey&color=yellow&logoColor=white&label=%20&style=flat-square)](https://colab.research.google.com/github/huggingface/deep-rl-class/blob/main/notebooks/unit8/unit8_part2.ipynb)
