# %% [markdown]
# # ML voor gestructureerde data
#
# ## [Input notebook](../structured_airbnb.ipynb)
#
# ## Algemene instructies
# - Je geeft je antwoord telkens na de ✍️. Na de 🔑 kan je _beschrijven_ hoe je tot dit antwoord kwam (gebruik de cel nummers in de input notebook ter referentie).
# - Er wordt enkel naar de beschrijving bij 🔑 gekeken indien je antwoord bij ✍️ fout is.

# %% [markdown]
# ### Q1
# ❓ Wat is de target variabele van het ML model?
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q2
# ❓ Welke ML modellen worden er gebruikt?
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q3
# ❓ Wat zijn de dimensies van de feature matrix?
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q4
# ❓ Met welke soort van data structuur hebben we te maken bij deze features?
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q5
# ❓ Geef de naam en waarden van minstens twee hyper parameters.
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q6
# ❓ Hoe wordt de data opgedeeld voor de training, validatie de test van de modellen en over hoeveel observaties gaat het in elk deel?
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q7
# ❓ Met welke soort _taak_ hebben we hier te maken?
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q8
# ❓ Met welke soort _ervaring_ hebben we hier te maken?
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q9
# ❓ Geef minstens twee voorbeelden van performantiematen (_aka score metrics_).
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q10
# ❓ Stel dat we moeten besparen op drie features, welke zouden we moeten kiezen?
#
# ✍️
#
# 🔑

# %% [markdown]
# ### Q11
# ❓ Welk model type geeft het beste resultaat en op basis waarvan wordt dit bepaald?
#
# ✍️
#
# 🔑
