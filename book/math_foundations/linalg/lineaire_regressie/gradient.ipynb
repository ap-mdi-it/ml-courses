# %% [markdown]
# # _SSE_ _Gradient_
#
# In deze sectie concentreren we ons eerst op de SSE functie in het geval we maar naar een parameter op zoek zijn (hetzij omdat het model maar één parameter heeft of we de andere parameter(s) reeds kennen). We krijgen dan een U-vormige curve te zien zoals hieronder afgebeeld.
#
# :::{tip}
# Je kan dit ook zien als je in de 3D visualisatie, het assenstelsel zo draait rond de verticale as, dat je recht op de $x$- of $y$-as kijkt.
# :::

# %%
from ml_courses.sim.derivative_viz import DerivativeVisualization

# %%
dv = DerivativeVisualization()
dv.plot()

# %% [markdown]
# Bij de Monte Carlo simulatie gaven we ons over aan het _willekeurig aftasten_ van de SSE functie. We zochten steeds naar een richting in de ruimte waarin we een _stapje naar beneden_ konden zetten. Het is echter wiskundig perfect mogelijk om op ieder punt te bepalen in welke richting de daling het grootst zal zijn. Dit brengt ons bij het concept van een **_raak- of tangentlijn_ op een bepaald punt van een functie waarvan de richtingscoëfficient (of _slope_) de "_afgeleide_" van die functie in dat punt wordt genoemd**.
#
# De illustratie hierboven toont het principe. We beginnen met een rechte die een **kwadratische functie**
#
# $$f(x) = x^2$$
#
# op twee punten snijdt: $(x_1, y_1)$ en $(x_2, y_2)$. Om de richtingscoëfficient te bepalen, rekenen we gewoon de verhouding uit tussen de afstand op de $y$-as ($\Delta y = y_2 - y_1$) en de afstand op de $x$-as ($\Delta x = x_2 - x_1$).
#
# $$
# \begin{aligned}
# \frac{\Delta y}{\Delta x}
# &= \frac{y_2 - y_1}{\Delta x} \cr
# &= \frac{f(x_1 + \Delta x) - f(x_1)}{\Delta x} \cr
# &= \frac{(x_1 + \Delta x)^2 - x_1^2}{\Delta x} \cr
# &= \frac{x_1^2 + 2x_1\Delta x + \Delta x^2 - x_1^2}{\Delta x} \cr
# &= \frac{2x_1\Delta x + \Delta x^2}{\Delta x} \cr
# &= 2x_1 + \Delta x
# \end{aligned}
# $$
#
# Dit geeft al een eerste idee van de richting waarin de SSE (het sterkst) daalt. We kunnen een preciezere richting krijgen door het interval kleiner en kleiner te maken. **In het theoretisch kleinste interval ($\lim_{\Delta x\to 0}$) spreken we niet meer van een snijlijn, maar een raak- of tangentlijn in een bepaald punt en niet meer van de richtingscoëfficient van die lijn, maar van de afgeleide van de functie in dat punt**. Als we in het kwadratische geval $\Delta x$ op $0$ zetten, krijgen we:
#
# $$
# \begin{aligned}
# \lim_{\Delta x\to 0} \frac{\Delta y}{\Delta x} &= \frac{\partial y}{\partial x} \cr
# &= 2x
# \end{aligned}
# $$
